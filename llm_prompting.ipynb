# %% [markdown]
# <a href="https://colab.research.google.com/github/pxs1990/NLP_LLM/blob/main/llm_prompting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# llm_prompting/
#
#  ├── app.py
#
#  ├── config.py
#
#  ├── prompts.py
#
#  ├── requirements.txt
#
#  ├── .env
#
#  └── .gitignore

# %%
# .env
OPENAI_API_KEY=sk-xxxxxxxxxxxxxxxxxxxx
OPENAI_MODEL=gpt-4.1-mini

# %%
# config.py
from dotenv import load_dotenv
import os

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_MODEL = os.getenv("OPENAI_MODEL", "gpt-4.1-mini")

if not OPENAI_API_KEY:
    raise RuntimeError("OPENAI_API_KEY is not set")

# %%
# prompts.py
SENTIMENT_PROMPT = """
You are a sentiment classification model.

Rules:
- Only return one word
- Allowed values: Positive, Negative

Text:
{text}
"""

# %%
# app.py
from openai import OpenAI
from config import OPENAI_API_KEY, OPENAI_MODEL
from prompts import SENTIMENT_PROMPT

client = OpenAI(api_key=OPENAI_API_KEY)

def classify_sentiment(text: str) -> str:
    response = client.responses.create(
        model=OPENAI_MODEL,
        input=SENTIMENT_PROMPT.format(text=text)
    )
    return response.output_text.strip()

if __name__ == "__main__":
    text = "The product stopped working in two days"
    result = classify_sentiment(text)
    print("Sentiment:", result)
